# %% [raw]
# ---
# self-contained: true
# title: "Midterm Part 1"
# format:
#   html:
#     theme: None
# author: "Samuel Lonac"
# ---

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("NationalParksDataCleaned.csv")
df.head()
# Out:
#    trail_id                          name                          area_name  \
# 0  10000013       McKittrick Canyon Trail  Guadalupe Mountains National Park
# 1  10000030    Dorr Mountain Ladder Trail               Acadia National Park
# 2  10000049     Rendezvous Mountain Trail          Grand Teton National Park
# 3  10000054  Sourdough Ridge Nature Trail        Mount Rainier National Park
# 4  10000147              Boston Run Trail      Cuyahoga Valley National Park
#
#     city_name  state_name   country_name  popularity     length  \
# 0   Salt Flat       Texas  United States     11.5435  32508.668
# 1  Bar Harbor       Maine  United States     17.7959   4345.218
# 2      Wilson     Wyoming  United States      4.6573  11104.446
# 3     Ashford  Washington  United States     15.5555   6276.426
# 4   Peninsula        Ohio  United States     10.5799   4988.954
#
#    elevation_gain  difficulty_rating    route_type  visitor_usage  avg_rating  \
# ...

# %% [markdown]
# ## Part One

# %% [markdown]
# 1.1

# %%
df[df['state_name'] == "California"].sort_values('length', ascending = False).head(4)
# Out:
#       trail_id                                  name  \
# 3264  10501331                       John Muir Trail
# 168   10004781   John Muir Trail via Yosemite Valley
# 2234  10270059  Ridgecrest to Death Valley OHV Trail
# 3129  10418330                         Big SEKI Loop
#
#                        area_name        city_name  state_name   country_name  \
# 3264      Yosemite National Park        Lone Pine  California  United States
# 168       Yosemite National Park  Yosemite Valley  California  United States
# 2234  Death Valley National Park       Ridgecrest  California  United States
# 3129  Kings Canyon National Park             Hume  California  United States
#
#       popularity      length  elevation_gain  difficulty_rating  \
# 3264      0.9673  339570.740      13165.8360                  3
# 168      24.0723  326856.954      14029.9440                  5
# 2234      3.6185  266989.506       3045.8664                  3
# ...

# %%
df['length_miles'] = df['length'] * 0.000621371

# %%
df[df['name'] == "Big SEKI Loop"]
# Out:
#       trail_id           name                   area_name city_name  \
# 3129  10418330  Big SEKI Loop  Kings Canyon National Park      Hume
#
#       state_name   country_name  popularity      length  elevation_gain  \
# 3129  California  United States      2.1531  233676.168      10944.7584
#
#       difficulty_rating route_type  visitor_usage  avg_rating  num_reviews  \
# 3129                  7       loop            1.0         5.0            2
#
#      units  features_ada  features_beach  features_cave  features_city-walk  \
# 3129     i             0               0              0                   0
#
#       features_dogs  features_dogs-leash  features_dogs-no  features_forest  \
# 3129              0                    0                 0                1
#
#       features_historic-site  features_hot-springs  features_kids  \
# 3129                       0                     0              0
#
#       features_lake  features_partially-paved  features_paved  \
# ...

# %% [markdown]
# 1.2 Consider an “easy” trail to be one that has an elevation gain of less than 500 meters, a distance of less than 5 kilometers, and a difficulty rating below 4

# %%
easy_trails = df[(df['elevation_gain'] < 500) & (df['length'] < 5000) & (df['difficulty_rating'] < 4)]

# %%
easy_trails[easy_trails['state_name'] == "California"].sort_values('avg_rating', ascending = False)
# Out:
#       trail_id                                             name  \
# 1161  10036245                                Lookout Peak Hike
# 2695  10311983                                 Crest View Trail
# 3225  10483854  Rattlesnake Canyon from Indian Cove Picnic Area
# 3201  10472836                               Crystal Lake Trail
# 681   10024378                         Saline Valley Hot Spring
# ...        ...                                              ...
# 2217  10269465                                      Reggie Dome
# 555   10015941                            Arch Point Loop Trail
# 2014  10261704                     Jack Gunn Maltese Peak Trail
# 2240  10270254                                       Pride Rock
# 3222  10483742                             Titus Canyon Narrows
#
#                           area_name         city_name  state_name  \
# 1161          Sequoia National Park            Dunlap  California
# ...

# %% [markdown]
# 1.3

# %%
land_trails = df[df['name'].str.contains('Land', case=False)]
len(land_trails)
# Out:
# 61

# %% [markdown]
# 1.4

# %%
np_trails_new = df[['avg_rating', 'difficulty_rating', 'popularity', 'visitor_usage']]

# %%
np_trails_new
# Out:
#       avg_rating  difficulty_rating  popularity  visitor_usage
# 0            4.5                  3     11.5435            2.0
# 1            4.5                  5     17.7959            3.0
# 2            4.5                  5      4.6573            2.0
# 3            4.5                  1     15.5555            2.0
# 4            4.0                  3     10.5799            3.0
# ...          ...                ...         ...            ...
# 3308         4.5                  1      0.0000            3.0
# 3309         0.0                  3      0.1941            1.0
# 3310         4.5                  5      0.0000            2.0
# 3311         5.0                  5      0.0000            2.0
# 3312         0.0                  3      0.0000            2.0
#
# [3313 rows x 4 columns]

# %%
#from plotnine import ggplot, aes, geom_density, facet_wrap, ggtitle

#(ggplot(np_trails_new, aes(x="score"))
#+ geom_density()
#+ facet_wrap('~ measure', scales = 'free')
#+ ggtitle("Overall distribution of various trail scores in National parks")
#)

# %% [markdown]
# 1.5

# %%
ca_parks = df[df['state_name'] == 'California']

# %%
help(geom_bar)
# Out:
# Help on class geom_bar in module plotnine.geoms.geom_bar:
#
# class geom_bar(plotnine.geoms.geom_rect.geom_rect)
#  |  geom_bar(mapping: 'Aes | None' = None, data: 'DataLike | None' = None, **kwargs: 'Any')
#  |
#  |  Bar plot
#  |
#  |
#  |  .. rubric:: Usage
#  |
#  |  ::
#  |
#  |      geom_bar(mapping=None, data=None, stat='count', position='stack', na_rm=False,
#  |               inherit_aes=True, show_legend=None, raster=False, width=None,
#  |               **kwargs)
#  |
#  |  Only the ``data`` and ``mapping`` can be positional, the rest must
#  |  be keyword arguments. ``**kwargs`` can be aesthetics (or parameters)
#  |  used by the ``stat``.
#  |
#  |
#  |  Parameters
#  |  ----------
#  |  mapping : aes, optional
#  |      Aesthetic mappings created with :meth:`~plotnine.aes`. If specified and :py:`inherit.aes=True`, it is combined with the default mapping for the plot. You must supply mapping if there is no plot mapping.
#  |
#  |      =============== ===============
# ...

# %%
#from plotnine import geom_bar, labs, stat_identity, scale_y_continous
#from plotnine.scales import scale_y_log10

#(ggplot(ca_parks, aes(x="area_name", y="num_reviews", fill = "area_name"))
#+ geom_bar()
#+ scale_y_log10()
#+ scale_y_continuous(guide=False)
#+ labs(
  #x = "",
  #y = "",
  #title = "Number of reviews per trail for CA Parks"
#)
#+ stat_identity()
#+ theme(axis.ticks.x.bottom=element_text(rotation=75, hjust=1))
#)
